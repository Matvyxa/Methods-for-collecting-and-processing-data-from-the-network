# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd

# %%
def _parser_hh(vacancy):

    vacancy_date = []
    
    params = {
        'clusters':'true', \
        'area':'1', \
        'enable_snippets':'true', \
        'salary':'', \
        'st':'searchVacancy', \
        'text':'Инженер сметчик'
    }
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
    }

    link = 'https://hh.ru/search/vacancy/'
       
    html = requests.get(link, params=params, headers=headers)
    
    if html.ok:
        parsed_html = bs(html.text,'html.parser')
        
        page_block = parsed_html.find('div', {'data-qa': 'pager-page'})
        if not page_block:
            last_page = int('1')
        else:
            last_page = int(page_block.find_all('a', {'class': 'bloko-button HH-Pager-Controls-Next HH-Pager-Control'})[-2].getText())
        
    
    
    for page in range(0, last_page):
        params['page'] = page
        html = requests.get(link, params=params, headers=headers)
        
        if html.ok:
            parsed_html = bs(html.text,'html.parser')
            
            vacancy_items = parsed_html.find('div', {'data-qa': 'vacancy-serp__results'}) \
                                        .find_all('div', {'class': 'vacancy-serp-item'})
                
            for item in vacancy_items:
                vacancy_date.append(_parser_item_hh(item))
                
    return vacancy_date

# %%
def _parser_item_hh(item):

    vacancy_date = {}
    
    # vacancy_name
    vacancy_name = item.find('span', {'class': 'resume-search-item__name'}) \
                        .getText() \
                        .replace(u'\xa0', u' ')
    
    vacancy_date['vacancy_name'] = vacancy_name
    
    # company_name
    company_name = item.find('a', {'data-qa': 'vacancy-serp__vacancy-employer'}).getText()
    
    vacancy_date['company_name'] = company_name
    
    # city
    city = item.find('span', {'data-qa': 'vacancy-serp__vacancy-address'}) \
                .getText() \
                .split(', ')[0]
    
    vacancy_date['city'] = city
    
    
    #salary
    salary = item.find('span', {'data-qa': 'vacancy-serp__vacancy-compensation'})
    if not salary:
        salary_min = None
        salary_max = None
        salary_currency = None
    else:
        salary = salary.getText() \
                        .replace(u'\xa0', u'')
        
        salary = re.split(r'\s|-', salary)
        
        if salary[0] == 'до':
            salary_min = None
            salary_max = int(salary[1])
        elif salary[0] == 'от':
            salary_min = int(salary[1])
            salary_max = None
        else:
            salary_min = int(salary[0])
            salary_max = int(salary[1])            
        
        salary_currency = salary[2]
        
    vacancy_date['salary_min'] = salary_min
    vacancy_date['salary_max'] = salary_max
    vacancy_date['salary_currency'] = salary_currency
    
    # link
    
    vacancy_link = item.find('h1', {'class': 'bloko-header-1'}) \
                        
    
    vacancy_date['vacancy_link'] = vacancy_link 
    
    
    # site
    vacancy_date['site'] = 'hh.ru'
    
    return vacancy_date

# %%
def _parser_superjob(vacancy):
    vacancy_date = []
    
    params = {
        'keywords': 'inzhener smetchik', \
        'page': '1'
    }
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
    }
    
    link = 'https://www.superjob.ru/vacancy/search/'
       
    html = requests.get(link, params=params, headers=headers)
    
    if html.ok:
        parsed_html = bs(html.text,'html.parser')
    
        page_block = parsed_html.find('a', {'class': 'icMQ_ _1_Cht _3ze9n f-test-button-1 f-test-button_active f-test-link-1 '})
    if not page_block:
        last_page = 1
    else:
        page_block = page_block.findParent()
        last_page = int(page_block.find_all('a')[-2].getText())
    
    for page in range(0, last_page + 1):
        params['page'] = page
        html = requests.get(link, params=params, headers=headers)
        
        if html.ok:
            parsed_html = bs(html.text,'html.parser')
            vacancy_items = parsed_html.find_all('div', {'class': '_3mfro PlM3e _2JVkc _3LJqf'})
                        
            for item in vacancy_items:
                vacancy_date.append(_parser_item_superjob(item))
                
    return vacancy_date

# %%
def _parser_item_superjob(item):

    vacancy_date = {}
    
    # vacancy_name
    vacancy_name = item.find_all('a', {'class': 'icMQ_ _6AfZ9 f-test-link-Inzhener-smetchik_slabotochnyh_sistem _2JivQ _1UJAN'})
    if len(vacancy_name) > 1:
        vacancy_name = vacancy_name[-2].getText()
    else:
        vacancy_name = vacancy_name[0].getText()
    vacancy_date['vacancy_name'] = vacancy_name
    
    # company_name
    company_name = item.find('a', {'class': 'icMQ_ _6AfZ9 f-test-link-Inzhener-smetchik_slabotochnyh_sistem _2JivQ _1UJAN'})
    
    if not company_name:
        company_name = item.findParent() \
                            .find('a', {'class': 'icMQ_ _205Zx f-test-link-Piran-IT _25-u7'}) \
                            .getText()
    else:
        company_name = company_name.getText()
    
    vacancy_date['company_name'] = company_name
    
    # city
    company_location = item.find('span', {' '}) \
                            .findChildren()[1] \
                            .getText() \
                            .split(',')
    
    vacancy_date['city'] = company_location[0]
    
    
    #salary
    salary = item.find('a', {'class': 'icMQ_ _6AfZ9 f-test-link-Veduschij_inzhener-smetchik_(obschestroj) _2JivQ _1UJAN'}) \
                  .findChildren()
    if not salary:
        salary_min = None
        salary_max = None
        salary_currency = None
    else:
        salary_currency = salary[-1].getText()
        is_check_sarary = item.find('a', {'class': 'icMQ_ _6AfZ9 f-test-link-Veduschij_inzhener-smetchik_(obschestroj) _2JivQ _1UJAN'}) \
                                .getText() \
                                .replace(u'\xa0', u' ') \
                                .split(' ', 1)[0]
        if is_check_sarary == 'до' or len(salary) == 2:
            salary_min = None
            salary_max = int(salary[0].getText() \
                                        .replace(u'\xa0', u''))
        elif is_check_sarary == 'от':
            salary_min = int(salary[0].getText() \
                                         .replace(u'\xa0', u''))
            salary_max = None
        else:
            salary_min = int(salary[0].getText() \
                                         .replace(u'\xa0', u''))
            salary_max = int(salary[2].getText() \
                                         .replace(u'\xa0', u''))           
        
    vacancy_date['salary_min'] = salary_min
    vacancy_date['salary_max'] = salary_max
    vacancy_date['salary_currency'] = salary_currency
    
    
    # link
    vacancy_link = item.find_all('Инженер сметчик')
    
    if len(vacancy_link) > 1:
        vacancy_link = vacancy_link[-2]['href']
    else:
        vacancy_link = vacancy_link[0]['href']
    
    vacancy_date['vacancy_link'] = f'https://www.superjob.ru{vacancy_link}'
    
    # site
    vacancy_date['site'] = 'www.superjob.ru'
    
    return vacancy_date

# %%
def parser_vacancy(vacancy):
        
    vacancy_date = []
    vacancy_date.extend(_parser_hh(vacancy))
    vacancy_date.extend(_parser_superjob(vacancy))
    
    df = pd.DataFrame(vacancy_date)

    return df

# %%
vacancy = 'Инженер сметчик'
df = parser_vacancy(vacancy)

# %%
df[1:300]
# Out:
#                                          vacancy_name  \
# 1                          Инженер-сметчик (удаленно)
# 2                                     Инженер-сметчик
# 3                          Помощник инженера-сметчика
# 4                                     Инженер-сметчик
# 5                             Главный инженер-сметчик
# 6                                     Инженер-сметчик
# 7                                     Инженер-сметчик
# 8                                     Инженер-сметчик
# 9                          Инженер-сметчик (Удаленно)
# 10  Инженер-сметчик в сфере малоэтажного домострое...
# 11                                    Инженер-сметчик
# 12                                  Сметчик-строитель
# 13                                    Инженер-сметчик
# 14                                    Инженер-сметчик
# 15                                    Инженер-сметчик
# 16                                    Инженер-сметчик
# 17                                    Инженер-сметчик
# 18                            Ведущий инженер-сметчик
# 19                                    Инженер-сметчик
# 20                                    Инженер-сметчик
# 21                         Инженер-Сметчик (Замерщик)
# 22                              Инженер-сметчик (смр)
# 23                                    Инженер-сметчик
# 24                                    Инженер-сметчик
# 25                                    Инженер-сметчик
# 26                                    Инженер-сметчик
# 27                                    Инженер-сметчик
# 28                         Помощник инженера-сметчика
# 29                              Инженер ПТО / Сметчик
# 30                            Ведущий инженер-сметчик
# 31                 Главный специалист инженер-сметчик
# 32                    Инженер-сметчик (строительство)
# 33  Ведущий специалист по ценообразованию / Ведущи...
# 34  Инженер-сметчик (специалист сметного отдела/ве...
# 35                                    Инженер-сметчик
# 36                                    Инженер-сметчик
# 37                                    Инженер-сметчик
# 38              Инженер-сметчик (электрооборудование)
# 39                                    Инженер-сметчик
# 40                                    Инженер-сметчик
# 41                Ведущий инженер-сметчик (общестрой)
# 42  Ведущий инженер-сметчик (инженер по ценообразо...
# 43                                    Инженер-сметчик
# 44                                    Инженер-сметчик
# 45                                    Инженер-сметчик
# 46                                    Инженер-сметчик
# 47                                    Инженер-сметчик
# 48                                    Инженер-сметчик
# 49                            Ведущий инженер-сметчик
#
#                                          company_name    city  salary_min  \
# 1                                               Domeo  Москва     30000.0
# 2                   ООО Генерация (Generation Invest)  Москва    125000.0
# 3                                  ООО МосСервисСтрой  Москва     40000.0
# 4                                             ООО УСР  Москва     80000.0
# 5                                              Инград  Москва    120000.0
# 6               ООО Инжиниринговая Компания Главстрой  Москва     80000.0
# 7                                     ООО Бас Капитал  Москва     80000.0
# 8                                ФГУП ГСУ ФСИН России  Москва         NaN
# 9                                     ООО Гранд Строй  Москва     40000.0
# 10                                   ГК Строй Коттедж  Москва     80000.0
# 11                                    ООО Перспектива  Москва     80000.0
# 12                                  ООО Кенмер Градня  Москва     80000.0
# 13                                             Инград  Москва    100000.0
# 14                                            ООО АРС  Москва     75000.0
# 15                                 ООО МосСервисСтрой  Москва     70000.0
# 16                                    АО Москапремонт  Москва     80000.0
# 17                                        ООО Спутник  Москва     80000.0
# 18                                  ООО СпецСитиСтрой  Москва     80000.0
# 19  ООО Строительно-производственная компания МЕГАПИР  Москва     80000.0
# 20                                 ООО СПК-Инжиниринг  Москва     90000.0
# 21                                ООО Мастера Ремонта  Москва    110000.0
# 22                                        ООО СтарТЕН  Москва     80000.0
# 23                                    ООО Арт Импульс  Москва    100000.0
# 24                  ООО Комбинат Промышленной Отделки  Москва     90000.0
# 25                                        ООО Гранель  Москва    100000.0
# 26                     ООО Первая Отделочная Компания  Москва     70000.0
# 27                                 ООО Борисоглебское  Москва     80000.0
# 28                                       МЭГЛИ ПРОЕКТ  Москва     40000.0
